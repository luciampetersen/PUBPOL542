# %%
link="https://github.com/elstephens1216/PUBPOL542/raw/main/AggregatedCulturalSpacesData.xlsx"

import pandas as pd

allzips=pd.read_excel(link)
allzips
# Out:
#      Unnamed: 0 zipcode  culturalspaces
# 0             0   10006               1
# 1             1   10015               1
# 2             2   10020               1
# 3             3   10105               1
# 4             4   10201               1
# ..          ...     ...             ...
# 237         237   98195              15
# 238         238   98198               3
# 239         239   98199               8
# 240         240   98288               2
# 241         241   98424               1
#
# [242 rows x 3 columns]

# %%
allzips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      242 non-null    int64
#  1   zipcode         242 non-null    object
#  2   culturalspaces  242 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 5.8+ KB

# %%
# allzips.zipcode is a string (object)..then
allzips.zipcode.str.startswith('981')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 237     True
# 238     True
# 239     True
# 240    False
# 241    False
# Name: zipcode, Length: 242, dtype: bool

# %%
allzips['inSeattle']=allzips.zipcode.str.startswith('981')

# %%
allzips
# Out:
#      Unnamed: 0 zipcode  culturalspaces  inSeattle
# 0             0   10006               1      False
# 1             1   10015               1      False
# 2             2   10020               1      False
# 3             3   10105               1      False
# 4             4   10201               1      False
# ..          ...     ...             ...        ...
# 237         237   98195              15       True
# 238         238   98198               3       True
# 239         239   98199               8       True
# 240         240   98288               2      False
# 241         241   98424               1      False
#
# [242 rows x 4 columns]

# %%
# then
seattleZips=allzips[allzips.inSeattle==True]

# %%
#result
seattleZips
# Out:
#      Unnamed: 0 zipcode  culturalspaces  inSeattle
# 204         204   98101              54       True
# 205         205  98101-               1       True
# 206         206   98102              20       True
# 207         207   98103              77       True
# 208         208   98104              87       True
# 209         209   98105              64       True
# 210         210   98106               8       True
# 211         211   98107              35       True
# 212         212   98108              36       True
# 213         213   98109              48       True
# 214         214   98112              16       True
# 215         215   98115              27       True
# 216         216   98116              19       True
# 217         217  98116-               1       True
# 218         218   98117              11       True
# 219         219   98118              35       True
# 220         220   98119              18       True
# ...

# %%
WhenYouFind="-"
ReplaceWith=""

# %%
seattleZips.columns.str.replace(WhenYouFind,replaceWith,regex=True).str.lower()
# Out:
# Index(['unnamed: 0', 'zipcode', 'culturalspaces', 'inseattle'], dtype='object')

# %%
df = df.replace('-','', regex=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-e622d195ccdb> in <module>
# ----> 1 df = df.replace('-','', regex=True)
#
# NameError: name 'df' is not defined

# %%
seattleZips = seattleZips.replace('-','', regex=True)

# %%
seattleZips
# Out:
#      Unnamed: 0 zipcode  culturalspaces  inSeattle
# 204         204   98101              54       True
# 205         205   98101               1       True
# 206         206   98102              20       True
# 207         207   98103              77       True
# 208         208   98104              87       True
# 209         209   98105              64       True
# 210         210   98106               8       True
# 211         211   98107              35       True
# 212         212   98108              36       True
# 213         213   98109              48       True
# 214         214   98112              16       True
# 215         215   98115              27       True
# 216         216   98116              19       True
# 217         217   98116               1       True
# 218         218   98117              11       True
# 219         219   98118              35       True
# 220         220   98119              18       True
# ...

# %%
seattleZips['zipcode']=seattleZips['zipcode'].str.strip()

# %%
seattleZips
# Out:
#      Unnamed: 0 zipcode  culturalspaces  inSeattle
# 204         204   98101              54       True
# 205         205   98101               1       True
# 206         206   98102              20       True
# 207         207   98103              77       True
# 208         208   98104              87       True
# 209         209   98105              64       True
# 210         210   98106               8       True
# 211         211   98107              35       True
# 212         212   98108              36       True
# 213         213   98109              48       True
# 214         214   98112              16       True
# 215         215   98115              27       True
# 216         216   98116              19       True
# 217         217   98116               1       True
# 218         218   98117              11       True
# 219         219   98118              35       True
# 220         220   98119              18       True
# ...

# %%
seattleZips['zipcode']=seattleZips['zipcode'].str.strip()

# %%
seattleZips
# Out:
#      Unnamed: 0 zipcode  culturalspaces  inSeattle
# 204         204   98101              54       True
# 205         205   98101               1       True
# 206         206   98102              20       True
# 207         207   98103              77       True
# 208         208   98104              87       True
# 209         209   98105              64       True
# 210         210   98106               8       True
# 211         211   98107              35       True
# 212         212   98108              36       True
# 213         213   98109              48       True
# 214         214   98112              16       True
# 215         215   98115              27       True
# 216         216   98116              19       True
# 217         217   98116               1       True
# 218         218   98117              11       True
# 219         219   98118              35       True
# 220         220   98119              18       True
# ...

# %%
import pandas as pd
location='https://github.com/luciampetersen/PUBPOL542/blob/main/'
fileXLSX=location+'CleanedSeattleIncomeByZip2013.xlsx?raw=true'
dataExcel=pd.read_excel(fileXLSX)

# %%
dataExcel
# Out:
#     zipcode  number_of_returns     avg_AGI
# 0     98101               7890  136.148796
# 1     98102              15880   94.815680
# 2     98103              28150   85.427673
# 3     98104               6580   98.656079
# 4     98105              15400  108.521234
# 5     98106              12500   50.077520
# 6     98107              14480   77.424862
# 7     98108              11780   50.012733
# 8     98109              15300  108.843856
# 9     98110              11310  132.369231
# 10    98112              12130  202.574526
# 11    98115              25370  100.746709
# 12    98116              13660   98.377599
# 13    98117              17560   93.953588
# 14    98118              22620   56.957781
# 15    98119              12450  111.552450
# 16    98121               8760  128.087100
# 17    98122              19510   77.256996
# 18    98125              20000   64.398200
# 19    98126              10950   70.937534
# 20    98133              24090   55.067206
# ...

# %%
seattleZips
# Out:
#      Unnamed: 0 zipcode  culturalspaces  inSeattle
# 204         204   98101              54       True
# 205         205   98101               1       True
# 206         206   98102              20       True
# 207         207   98103              77       True
# 208         208   98104              87       True
# 209         209   98105              64       True
# 210         210   98106               8       True
# 211         211   98107              35       True
# 212         212   98108              36       True
# 213         213   98109              48       True
# 214         214   98112              16       True
# 215         215   98115              27       True
# 216         216   98116              19       True
# 217         217   98116               1       True
# 218         218   98117              11       True
# 219         219   98118              35       True
# 220         220   98119              18       True
# ...

# %%
del seattleZips ['Unnamed: 0']

# %%
seattleZips
# Out:
#     zipcode  culturalspaces  inSeattle
# 204   98101              54       True
# 205   98101               1       True
# 206   98102              20       True
# 207   98103              77       True
# 208   98104              87       True
# 209   98105              64       True
# 210   98106               8       True
# 211   98107              35       True
# 212   98108              36       True
# 213   98109              48       True
# 214   98112              16       True
# 215   98115              27       True
# 216   98116              19       True
# 217   98116               1       True
# 218   98117              11       True
# 219   98118              35       True
# 220   98119              18       True
# 221   98121              38       True
# 222   98122              88       True
# 223   98125               4       True
# 224   98126               9       True
# 225   98133               4       True
# 226   98134              23       True
# ...

# %%
del seattleZips ['inSeattle']

# %%
seattleZips
# Out:
#     zipcode  culturalspaces
# 204   98101              54
# 205   98101               1
# 206   98102              20
# 207   98103              77
# 208   98104              87
# 209   98105              64
# 210   98106               8
# 211   98107              35
# 212   98108              36
# 213   98109              48
# 214   98112              16
# 215   98115              27
# 216   98116              19
# 217   98116               1
# 218   98117              11
# 219   98118              35
# 220   98119              18
# 221   98121              38
# 222   98122              88
# 223   98125               4
# 224   98126               9
# 225   98133               4
# 226   98134              23
# 227   98136               7
# 228   98144              26
# 229   98145               1
# 230   98146               4
# 231   98148               1
# 232   98154               1
# 233   98155               4
# 234   98166               7
# 235   98168               2
# ...

# %%
seattleZips.dtypes
# Out:
# zipcode           object
# culturalspaces     int64
# dtype: object

# %%
dataExcel.dtypes
# Out:
# zipcode                int64
# number_of_returns      int64
# avg_AGI              float64
# dtype: object

# %%
getCodes = lambda COLUMN:COLUMN.cat.codes

# %%
seattleZips['zipcode'].astype(int)
# Out:
# 204    98101
# 205    98101
# 206    98102
# 207    98103
# 208    98104
# 209    98105
# 210    98106
# 211    98107
# 212    98108
# 213    98109
# 214    98112
# 215    98115
# 216    98116
# 217    98116
# 218    98117
# 219    98118
# 220    98119
# 221    98121
# 222    98122
# 223    98125
# 224    98126
# 225    98133
# 226    98134
# 227    98136
# 228    98144
# 229    98145
# 230    98146
# 231    98148
# 232    98154
# 233    98155
# 234    98166
# 235    98168
# 236    98188
# 237    98195
# 238    98198
# 239    98199
# Name: zipcode, dtype: int64

# %%
seattleZips.dtypes
# Out:
# zipcode           object
# culturalspaces     int64
# dtype: object

# %%
DF=seattleZips

# %%
getCodes = lambda COLUMN:COLUMN.cat.codes

# %%
import pandas as pd

df = pd.read_excel (r'/Users/luciapetersen/Desktop/crimedata.xlsx')   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
print (df)
# Out:
#     zipcode  cases_reported
# 0     98101            5361
# 1     98102            1752
# 2     98103            4053
# 3     98104            3513
# 4     98105            2958
# 5     98106             670
# 6     98107            3101
# 7     98108            1569
# 8     98109            2681
# 9     98112            2140
# 10    98115            2401
# 11    98116            1056
# 12    98117            3184
# 13    98118            1624
# 14    98119            1654
# 15    98121            2179
# 16    98122            1712
# 17    98125            3184
# 18    98126            1194
# 19    98133            1058
# 20    98134             674
# 21    98136            1396
# 22    98144            2369
# 23    98146            1041
# 24    98168             102
# 25    98177             378
# 26    98178             355
# 27    98199             680

# %%
dataExcel.merge(df)
# Out:
#     zipcode  number_of_returns     avg_AGI  cases_reported
# 0     98101               7890  136.148796            5361
# 1     98102              15880   94.815680            1752
# 2     98103              28150   85.427673            4053
# 3     98104               6580   98.656079            3513
# 4     98105              15400  108.521234            2958
# 5     98106              12500   50.077520             670
# 6     98107              14480   77.424862            3101
# 7     98108              11780   50.012733            1569
# 8     98109              15300  108.843856            2681
# 9     98112              12130  202.574526            2140
# 10    98115              25370  100.746709            2401
# 11    98116              13660   98.377599            1056
# 12    98117              17560   93.953588            3184
# 13    98118              22620   56.957781            1624
# 14    98119              12450  111.552450            1654
# ...

# %%
df
# Out:
#     zipcode  cases_reported
# 0     98101            5361
# 1     98102            1752
# 2     98103            4053
# 3     98104            3513
# 4     98105            2958
# 5     98106             670
# 6     98107            3101
# 7     98108            1569
# 8     98109            2681
# 9     98112            2140
# 10    98115            2401
# 11    98116            1056
# 12    98117            3184
# 13    98118            1624
# 14    98119            1654
# 15    98121            2179
# 16    98122            1712
# 17    98125            3184
# 18    98126            1194
# 19    98133            1058
# 20    98134             674
# 21    98136            1396
# 22    98144            2369
# 23    98146            1041
# 24    98168             102
# 25    98177             378
# 26    98178             355
# 27    98199             680

# %%
dataExcel
# Out:
#     zipcode  number_of_returns     avg_AGI
# 0     98101               7890  136.148796
# 1     98102              15880   94.815680
# 2     98103              28150   85.427673
# 3     98104               6580   98.656079
# 4     98105              15400  108.521234
# 5     98106              12500   50.077520
# 6     98107              14480   77.424862
# 7     98108              11780   50.012733
# 8     98109              15300  108.843856
# 9     98110              11310  132.369231
# 10    98112              12130  202.574526
# 11    98115              25370  100.746709
# 12    98116              13660   98.377599
# 13    98117              17560   93.953588
# 14    98118              22620   56.957781
# 15    98119              12450  111.552450
# 16    98121               8760  128.087100
# 17    98122              19510   77.256996
# 18    98125              20000   64.398200
# 19    98126              10950   70.937534
# 20    98133              24090   55.067206
# ...

# %%
dataExcel.merge(df)
# Out:
#     zipcode  number_of_returns     avg_AGI  cases_reported
# 0     98101               7890  136.148796            5361
# 1     98102              15880   94.815680            1752
# 2     98103              28150   85.427673            4053
# 3     98104               6580   98.656079            3513
# 4     98105              15400  108.521234            2958
# 5     98106              12500   50.077520             670
# 6     98107              14480   77.424862            3101
# 7     98108              11780   50.012733            1569
# 8     98109              15300  108.843856            2681
# 9     98112              12130  202.574526            2140
# 10    98115              25370  100.746709            2401
# 11    98116              13660   98.377599            1056
# 12    98117              17560   93.953588            3184
# 13    98118              22620   56.957781            1624
# 14    98119              12450  111.552450            1654
# ...

# %%
seattleZips
# Out:
#     zipcode  culturalspaces
# 204   98101              54
# 205   98101               1
# 206   98102              20
# 207   98103              77
# 208   98104              87
# 209   98105              64
# 210   98106               8
# 211   98107              35
# 212   98108              36
# 213   98109              48
# 214   98112              16
# 215   98115              27
# 216   98116              19
# 217   98116               1
# 218   98117              11
# 219   98118              35
# 220   98119              18
# 221   98121              38
# 222   98122              88
# 223   98125               4
# 224   98126               9
# 225   98133               4
# 226   98134              23
# 227   98136               7
# 228   98144              26
# 229   98145               1
# 230   98146               4
# 231   98148               1
# 232   98154               1
# 233   98155               4
# 234   98166               7
# 235   98168               2
# ...

# %%
seattleZips = seattleZips.astype(int)

# %%
seattleZips.dtypes
# Out:
# zipcode           int64
# culturalspaces    int64
# dtype: object

# %%
dataExcel.merge(df)
# Out:
#     zipcode  number_of_returns     avg_AGI  cases_reported
# 0     98101               7890  136.148796            5361
# 1     98102              15880   94.815680            1752
# 2     98103              28150   85.427673            4053
# 3     98104               6580   98.656079            3513
# 4     98105              15400  108.521234            2958
# 5     98106              12500   50.077520             670
# 6     98107              14480   77.424862            3101
# 7     98108              11780   50.012733            1569
# 8     98109              15300  108.843856            2681
# 9     98112              12130  202.574526            2140
# 10    98115              25370  100.746709            2401
# 11    98116              13660   98.377599            1056
# 12    98117              17560   93.953588            3184
# 13    98118              22620   56.957781            1624
# 14    98119              12450  111.552450            1654
# ...

# %%
merge1=dataExcel.merge(df)

# %%
merge1
# Out:
#     zipcode  number_of_returns     avg_AGI  cases_reported
# 0     98101               7890  136.148796            5361
# 1     98102              15880   94.815680            1752
# 2     98103              28150   85.427673            4053
# 3     98104               6580   98.656079            3513
# 4     98105              15400  108.521234            2958
# 5     98106              12500   50.077520             670
# 6     98107              14480   77.424862            3101
# 7     98108              11780   50.012733            1569
# 8     98109              15300  108.843856            2681
# 9     98112              12130  202.574526            2140
# 10    98115              25370  100.746709            2401
# 11    98116              13660   98.377599            1056
# 12    98117              17560   93.953588            3184
# 13    98118              22620   56.957781            1624
# 14    98119              12450  111.552450            1654
# ...

# %%
merge2=merge1.merge(seattleZips)

# %%
merge2
# Out:
#     zipcode  number_of_returns     avg_AGI  cases_reported  culturalspaces
# 0     98101               7890  136.148796            5361              54
# 1     98101               7890  136.148796            5361               1
# 2     98102              15880   94.815680            1752              20
# 3     98103              28150   85.427673            4053              77
# 4     98104               6580   98.656079            3513              87
# 5     98105              15400  108.521234            2958              64
# 6     98106              12500   50.077520             670               8
# 7     98107              14480   77.424862            3101              35
# 8     98108              11780   50.012733            1569              36
# 9     98109              15300  108.843856            2681              48
# 10    98112              12130  202.574526            2140              16
# ...

# %%
merge2.columns=['zipcode','number_of_tax_returns','avg_AGI','crimes_reported','cultural_spaces']

# %%
merge2
# Out:
#     zipcode  number_of_tax_returns     avg_AGI  crimes_reported  \
# 0     98101                   7890  136.148796             5361
# 1     98101                   7890  136.148796             5361
# 2     98102                  15880   94.815680             1752
# 3     98103                  28150   85.427673             4053
# 4     98104                   6580   98.656079             3513
# 5     98105                  15400  108.521234             2958
# 6     98106                  12500   50.077520              670
# 7     98107                  14480   77.424862             3101
# 8     98108                  11780   50.012733             1569
# 9     98109                  15300  108.843856             2681
# 10    98112                  12130  202.574526             2140
# 11    98115                  25370  100.746709             2401
# 12    98116                  13660   98.377599             1056
# 13    98116                  13660   98.377599             1056
# ...

# %%
merge2.columns=['zipcode','num_of_tax_returns','avg_AGI','crimes_reported','cultural_spaces']

# %%
merge2
# Out:
#     zipcode  num_of_tax_returns     avg_AGI  crimes_reported  cultural_spaces
# 0     98101                7890  136.148796             5361               54
# 1     98101                7890  136.148796             5361                1
# 2     98102               15880   94.815680             1752               20
# 3     98103               28150   85.427673             4053               77
# 4     98104                6580   98.656079             3513               87
# 5     98105               15400  108.521234             2958               64
# 6     98106               12500   50.077520              670                8
# 7     98107               14480   77.424862             3101               35
# 8     98108               11780   50.012733             1569               36
# 9     98109               15300  108.843856             2681               48
# 10    98112               12130  202.574526             2140               16
# ...

# %%
del merge2['num_of_tax_returns']

# %%
merge2
# Out:
#     zipcode     avg_AGI  crimes_reported  cultural_spaces
# 0     98101  136.148796             5361               54
# 1     98101  136.148796             5361                1
# 2     98102   94.815680             1752               20
# 3     98103   85.427673             4053               77
# 4     98104   98.656079             3513               87
# 5     98105  108.521234             2958               64
# 6     98106   50.077520              670                8
# 7     98107   77.424862             3101               35
# 8     98108   50.012733             1569               36
# 9     98109  108.843856             2681               48
# 10    98112  202.574526             2140               16
# 11    98115  100.746709             2401               27
# 12    98116   98.377599             1056               19
# 13    98116   98.377599             1056                1
# 14    98117   93.953588             3184               11
# ...

# %%
url = 'https://raw.githubusercontent.com/jassymd96/SeattlePetData/main/petData.csv'
df = pd.read_csv(url, index_col=0)

# %%
df
# Out:
#             LicenseIssueDate Species  zipcode
# 0    2015-12-18T00:00:00.000     Cat    98117
# 1    2016-06-14T00:00:00.000     Cat    98117
# 2    2016-08-04T00:00:00.000     Cat    98121
# 3    2016-11-08T00:00:00.000     Cat    98106
# 4    2017-04-11T00:00:00.000     Cat    98102
# ..                       ...     ...      ...
# 984  2019-03-28T00:00:00.000     Cat    98117
# 985  2019-03-28T00:00:00.000     Cat    98116
# 986  2019-03-29T00:00:00.000     Cat    98121
# 987  2019-03-29T00:00:00.000     Cat    98125
# 988  2019-03-29T00:00:00.000     Cat    98136
#
# [989 rows x 3 columns]

# %%
del df['LicenseIssueDate']

# %%
df
# Out:
#     Species  zipcode
# 0       Cat    98117
# 1       Cat    98117
# 2       Cat    98121
# 3       Cat    98106
# 4       Cat    98102
# ..      ...      ...
# 984     Cat    98117
# 985     Cat    98116
# 986     Cat    98121
# 987     Cat    98125
# 988     Cat    98136
#
# [989 rows x 2 columns]

# %%
df.groupby('zipcode')

# %%
df.groupby('zipcode').count()
# Out:
#          Species
# zipcode
# 87122          1
# 98059          1
# 98101         12
# 98102         29
# 98103         84
# 98104          9
# 98105         47
# 98106         27
# 98107         60
# 98108         25
# 98109         37
# 98111          1
# 98112         30
# 98115         82
# 98116         44
# 98117         85
# 98118         36
# 98119         28
# 98121         23
# 98122         58
# 98125         54
# 98126         35
# 98133         47
# 98134          1
# 98136         20
# 98144         38
# 98146          7
# 98155          1
# 98177          9
# 98178         14
# 98198          1
# 98199         42
# 98507          1

# %%
petdata=df.groupby('zipcode').count()

# %%
petdata
# Out:
#          Species
# zipcode
# 87122          1
# 98059          1
# 98101         12
# 98102         29
# 98103         84
# 98104          9
# 98105         47
# 98106         27
# 98107         60
# 98108         25
# 98109         37
# 98111          1
# 98112         30
# 98115         82
# 98116         44
# 98117         85
# 98118         36
# 98119         28
# 98121         23
# 98122         58
# 98125         54
# 98126         35
# 98133         47
# 98134          1
# 98136         20
# 98144         38
# 98146          7
# 98155          1
# 98177          9
# 98178         14
# 98198          1
# 98199         42
# 98507          1

# %%
petdata.groupby('zipcode')['Species']

# %%
petdata
# Out:
#          Species
# zipcode
# 87122          1
# 98059          1
# 98101         12
# 98102         29
# 98103         84
# 98104          9
# 98105         47
# 98106         27
# 98107         60
# 98108         25
# 98109         37
# 98111          1
# 98112         30
# 98115         82
# 98116         44
# 98117         85
# 98118         36
# 98119         28
# 98121         23
# 98122         58
# 98125         54
# 98126         35
# 98133         47
# 98134          1
# 98136         20
# 98144         38
# 98146          7
# 98155          1
# 98177          9
# 98178         14
# 98198          1
# 98199         42
# 98507          1

# %%
petdata.reset_index()
# Out:
#     zipcode  Species
# 0     87122        1
# 1     98059        1
# 2     98101       12
# 3     98102       29
# 4     98103       84
# 5     98104        9
# 6     98105       47
# 7     98106       27
# 8     98107       60
# 9     98108       25
# 10    98109       37
# 11    98111        1
# 12    98112       30
# 13    98115       82
# 14    98116       44
# 15    98117       85
# 16    98118       36
# 17    98119       28
# 18    98121       23
# 19    98122       58
# 20    98125       54
# 21    98126       35
# 22    98133       47
# 23    98134        1
# 24    98136       20
# 25    98144       38
# 26    98146        7
# 27    98155        1
# 28    98177        9
# 29    98178       14
# 30    98198        1
# 31    98199       42
# 32    98507        1

# %%
petdata.dtypes
# Out:
# Species    int64
# dtype: object

# %%
petdata
# Out:
#          Species
# zipcode
# 87122          1
# 98059          1
# 98101         12
# 98102         29
# 98103         84
# 98104          9
# 98105         47
# 98106         27
# 98107         60
# 98108         25
# 98109         37
# 98111          1
# 98112         30
# 98115         82
# 98116         44
# 98117         85
# 98118         36
# 98119         28
# 98121         23
# 98122         58
# 98125         54
# 98126         35
# 98133         47
# 98134          1
# 98136         20
# 98144         38
# 98146          7
# 98155          1
# 98177          9
# 98178         14
# 98198          1
# 98199         42
# 98507          1

# %%
petdata.reset_index()
# Out:
#     zipcode  Species
# 0     87122        1
# 1     98059        1
# 2     98101       12
# 3     98102       29
# 4     98103       84
# 5     98104        9
# 6     98105       47
# 7     98106       27
# 8     98107       60
# 9     98108       25
# 10    98109       37
# 11    98111        1
# 12    98112       30
# 13    98115       82
# 14    98116       44
# 15    98117       85
# 16    98118       36
# 17    98119       28
# 18    98121       23
# 19    98122       58
# 20    98125       54
# 21    98126       35
# 22    98133       47
# 23    98134        1
# 24    98136       20
# 25    98144       38
# 26    98146        7
# 27    98155        1
# 28    98177        9
# 29    98178       14
# 30    98198        1
# 31    98199       42
# 32    98507        1

# %%
petdata2=petdata.reset_index()

# %%
petdata2
# Out:
#     zipcode  Species
# 0     87122        1
# 1     98059        1
# 2     98101       12
# 3     98102       29
# 4     98103       84
# 5     98104        9
# 6     98105       47
# 7     98106       27
# 8     98107       60
# 9     98108       25
# 10    98109       37
# 11    98111        1
# 12    98112       30
# 13    98115       82
# 14    98116       44
# 15    98117       85
# 16    98118       36
# 17    98119       28
# 18    98121       23
# 19    98122       58
# 20    98125       54
# 21    98126       35
# 22    98133       47
# 23    98134        1
# 24    98136       20
# 25    98144       38
# 26    98146        7
# 27    98155        1
# 28    98177        9
# 29    98178       14
# 30    98198        1
# 31    98199       42
# 32    98507        1

# %%
petdata2.dtypes
# Out:
# zipcode    int64
# Species    int64
# dtype: object

# %%
petdata2.columns=['zipcode','num_of_pets']

# %%
petdata2
# Out:
#     zipcode  num_of_pets
# 0     87122            1
# 1     98059            1
# 2     98101           12
# 3     98102           29
# 4     98103           84
# 5     98104            9
# 6     98105           47
# 7     98106           27
# 8     98107           60
# 9     98108           25
# 10    98109           37
# 11    98111            1
# 12    98112           30
# 13    98115           82
# 14    98116           44
# 15    98117           85
# 16    98118           36
# 17    98119           28
# 18    98121           23
# 19    98122           58
# 20    98125           54
# 21    98126           35
# 22    98133           47
# 23    98134            1
# 24    98136           20
# 25    98144           38
# 26    98146            7
# 27    98155            1
# 28    98177            9
# 29    98178           14
# 30    98198            1
# 31    98199           42
# 32    98507            1

# %%
merge3=merge2.merge(petdata2)

# %%
merge3
# Out:
#     zipcode     avg_AGI  crimes_reported  cultural_spaces  num_of_pets
# 0     98101  136.148796             5361               54           12
# 1     98101  136.148796             5361                1           12
# 2     98102   94.815680             1752               20           29
# 3     98103   85.427673             4053               77           84
# 4     98104   98.656079             3513               87            9
# 5     98105  108.521234             2958               64           47
# 6     98106   50.077520              670                8           27
# 7     98107   77.424862             3101               35           60
# 8     98108   50.012733             1569               36           25
# 9     98109  108.843856             2681               48           37
# 10    98112  202.574526             2140               16           30
# 11    98115  100.746709             2401               27           82
# ...

# %%
merge2
# Out:
#     zipcode     avg_AGI  crimes_reported  cultural_spaces
# 0     98101  136.148796             5361               54
# 1     98101  136.148796             5361                1
# 2     98102   94.815680             1752               20
# 3     98103   85.427673             4053               77
# 4     98104   98.656079             3513               87
# 5     98105  108.521234             2958               64
# 6     98106   50.077520              670                8
# 7     98107   77.424862             3101               35
# 8     98108   50.012733             1569               36
# 9     98109  108.843856             2681               48
# 10    98112  202.574526             2140               16
# 11    98115  100.746709             2401               27
# 12    98116   98.377599             1056               19
# 13    98116   98.377599             1056                1
# 14    98117   93.953588             3184               11
# ...

# %%
merge1
# Out:
#     zipcode  number_of_returns     avg_AGI  cases_reported
# 0     98101               7890  136.148796            5361
# 1     98102              15880   94.815680            1752
# 2     98103              28150   85.427673            4053
# 3     98104               6580   98.656079            3513
# 4     98105              15400  108.521234            2958
# 5     98106              12500   50.077520             670
# 6     98107              14480   77.424862            3101
# 7     98108              11780   50.012733            1569
# 8     98109              15300  108.843856            2681
# 9     98112              12130  202.574526            2140
# 10    98115              25370  100.746709            2401
# 11    98116              13660   98.377599            1056
# 12    98117              17560   93.953588            3184
# 13    98118              22620   56.957781            1624
# 14    98119              12450  111.552450            1654
# ...

# %%
merge3.to_excel(r'Desktop\group_merged.xlsx', index = False)

# %%
merge3.to_excel(r'/Users/luciapetersen/Desktop/group_merged.xlsx', sheet_name='Sheet1', index = False)
